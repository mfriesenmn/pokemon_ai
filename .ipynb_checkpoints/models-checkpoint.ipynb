# %%
 # Use train_test_split to create training and testing data
from sklearn.model_selection import train_test_split
from numpy.random import seed
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
import os
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC


seed(1)

type1_array = []
legendary_array = []

pokedex = pd.read_csv('Pokemon.csv')
pokedex.head()


y = pokedex['Legendary']
y2 = pokedex['Type 1']

X = pokedex.drop("Legendary", axis=1)
X = X.drop("#", axis=1)
X = X.drop("Name", axis=1)
X = X.drop("Type 1", axis=1)
X = X.drop("Type 2", axis=1)
X.head()
# Out:
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0    318  45      49       49       65       65     45           1
# 1    405  60      62       63       80       80     60           1
# 2    525  80      82       83      100      100     80           1
# 3    625  80     100      123      122      120     80           1
# 4    309  39      52       43       60       50     65           1

# %%
# All Models - Type 1

scores = []
for i in range(0,51):
    #Neural Network
    X_train, X_test, y_train, y_test = train_test_split(X, y2, stratify=y2, random_state=i)
    X_scaler = StandardScaler().fit(X_train)
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    label_encoder = LabelEncoder()

    y_train = label_encoder.fit_transform(y_train)
    y_test = label_encoder.fit_transform(y_test)

    y_train_categorical = to_categorical(y_train)
    y_test_categorical = to_categorical(y_test)
    
    model = Sequential()
    model.add(Dense(units=6, activation='relu', input_dim=8))
    model.add(Dense(units=18, activation='softmax'))
    
    model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    
    history = model.fit(
        X_train_scaled,
        y_train_categorical,
        epochs=100,
        shuffle = True,
        verbose = 0,
        validation_data=(X_test_scaled,y_test_categorical)
    )
    model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=0)
    

    #scores.append(model_accuracy)
    print('NN Test Acc: %.3f' % model_accuracy)
    
    #KNN 
    knn = KNeighborsClassifier(n_neighbors=17)
    knn.fit(X_train_scaled, y_train)
    knn_score = knn.score(X_test_scaled, y_test)
    #scores.append(knn_score)
    print('KNN Test Acc: %.3f' % knn_score)
    
    #Random Forest
    
    rf = RandomForestClassifier (n_estimators=300)
    rf = rf.fit(X_train, y_train)
    rf_score = rf.score(X_test, y_test)
    
    #scores.append(rf_score)
    print('RF Test Acc: %.3f' % rf_score)
    
    # SVM
    
    svm_model = SVC(kernel='linear')

    svm_model.fit(X_train, y_train)
    
    SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
      decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
      max_iter=-1, probability=False, random_state=None, shrinking=True,
      tol=0.001, verbose=False)
    
    svm_score = svm_model.score(X_test, y_test)
    
    print('SVM Test Acc: %.3f' % svm_score)
    

    
    type1_array.append([model_accuracy, knn_score, rf_score, svm_score])


type1_df = pd.DataFrame(type1_array, columns = ['Neural Network', 'KNN', 'Random Forest', 'SVM'])

type1_df.to_csv('generated_data/type1_models.csv')

type1_df.head()
# Out:
# NN Test Acc: 0.260
# KNN Test Acc: 0.195
# RF Test Acc: 0.235
# SVM Test Acc: 0.265
# NN Test Acc: 0.210
# KNN Test Acc: 0.185
# RF Test Acc: 0.270
# SVM Test Acc: 0.255
# NN Test Acc: 0.210
# KNN Test Acc: 0.215
# RF Test Acc: 0.240
# SVM Test Acc: 0.270
# NN Test Acc: 0.175
# KNN Test Acc: 0.210
# RF Test Acc: 0.205
# SVM Test Acc: 0.170
# NN Test Acc: 0.230
# KNN Test Acc: 0.245
# RF Test Acc: 0.315
# SVM Test Acc: 0.235
# RF Test Acc: 0.290
# SVM Test Acc: 0.230
# NN Test Acc: 0.195
# KNN Test Acc: 0.200
# RF Test Acc: 0.255
# SVM Test Acc: 0.215
# NN Test Acc: 0.205
# KNN Test Acc: 0.195
# RF Test Acc: 0.270
# SVM Test Acc: 0.240
# NN Test Acc: 0.235
# KNN Test Acc: 0.225
# RF Test Acc: 0.285
# SVM Test Acc: 0.265
# NN Test Acc: 0.195
# KNN Test Acc: 0.190
# RF Test Acc: 0.265
# SVM Test Acc: 0.200
# NN Test Acc: 0.200
# KNN Test Acc: 0.200
# RF Test Acc: 0.240
# SVM Test Acc: 0.235
# NN Test Acc: 0.180
# KNN Test Acc: 0.195
# RF Test Acc: 0.275
# SVM Test Acc: 0.170
# NN Test Acc: 0.235
# KNN Test Acc: 0.195
# RF Test Acc: 0.225
# SVM Test Acc: 0.220
# NN Test Acc: 0.220
# KNN Test Acc: 0.190
# RF Test Acc: 0.205
# SVM Test Acc: 0.270
# NN Test Acc: 0.165
# KNN Test Acc: 0.200
# RF Test Acc: 0.265
# SVM Test Acc: 0.210
# NN Test Acc: 0.190
# KNN Test Acc: 0.170
# RF Test Acc: 0.245
# SVM Test Acc: 0.295
# NN Test Acc: 0.185
# KNN Test Acc: 0.210
# RF Test Acc: 0.250
# SVM Test Acc: 0.220
# NN Test Acc: 0.220
# KNN Test Acc: 0.220
# RF Test Acc: 0.265
# SVM Test Acc: 0.265
# NN Test Acc: 0.230
# KNN Test Acc: 0.185
# RF Test Acc: 0.265
# SVM Test Acc: 0.240
# NN Test Acc: 0.215
# KNN Test Acc: 0.205
# RF Test Acc: 0.220
# SVM Test Acc: 0.255
# NN Test Acc: 0.155
# KNN Test Acc: 0.200
# RF Test Acc: 0.250
# SVM Test Acc: 0.245
# NN Test Acc: 0.250
# KNN Test Acc: 0.185
# RF Test Acc: 0.265
# SVM Test Acc: 0.275
# NN Test Acc: 0.210
# KNN Test Acc: 0.200
# RF Test Acc: 0.235
# SVM Test Acc: 0.250
# NN Test Acc: 0.190
# KNN Test Acc: 0.225
# RF Test Acc: 0.265
# SVM Test Acc: 0.240
# NN Test Acc: 0.180
# KNN Test Acc: 0.200
# RF Test Acc: 0.270
# SVM Test Acc: 0.190
#    Neural Network    KNN  Random Forest    SVM
# 0           0.260  0.195          0.235  0.265
# 1           0.210  0.185          0.270  0.255
# 2           0.210  0.215          0.240  0.270
# 3           0.175  0.210          0.205  0.170
# 4           0.230  0.245          0.315  0.235

# %%
boxplot = type1_df.boxplot(column=['Neural Network', 'KNN', 'Random Forest', 'SVM'])

boxplot.set_title('Type 1 - Model Accuracy')
boxplot.set_xlabel('Model Type')
boxplot.set_ylabel('Model Accuracy')


boxplot.figure.savefig('images/type1_accuracy.png')

# %%
# Comparison of Predictions By Type 1
predictions = pokedex[['Name',"Type 1"]]
# KNN Predictions
predicted_class_knn = label_encoder.inverse_transform(knn.predict(X_scaler.transform(X)))
# Neural Network Predictions
predicted_class_nn = label_encoder.inverse_transform(model.predict_classes(X_scaler.transform(X)))
# Random Forest Predictions
predicted_class_rf = label_encoder.inverse_transform(rf.predict(X))
# SVM Predictions
predicted_class_svm = label_encoder.inverse_transform(svm_model.predict(X))
# Creating a dataframe to compare data
predictions['KNN Prediction'] = predicted_class_knn
predictions['Neural Network Prediction'] = predicted_class_nn
predictions['Random Forest Preduction'] = predicted_class_rf
predictions['SVM Prediction'] = predicted_class_svm


predictions.to_csv('generated_data/type1_predictions_accuracy.csv')

predictions.head(40)
# Out:
# /Users/danielbernal/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# <ipython-input-4-74edc724ea3b>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictions['KNN Prediction'] = predicted_class_knn
# <ipython-input-4-74edc724ea3b>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictions['Neural Network Prediction'] = predicted_class_nn
# <ipython-input-4-74edc724ea3b>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictions['Random Forest Preduction'] = predicted_class_rf
# <ipython-input-4-74edc724ea3b>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictions['SVM Prediction'] = predicted_class_svm
#                          Name    Type 1 KNN Prediction  \
# 0                   Bulbasaur     Grass           Fire
# 1                     Ivysaur     Grass          Grass
# 2                    Venusaur     Grass          Water
# 3       VenusaurMega Venusaur     Grass           Fire
# 4                  Charmander      Fire          Water
# 5                  Charmeleon      Fire         Normal
# 6                   Charizard      Fire           Fire
# 7   CharizardMega Charizard X      Fire           Fire
# 8   CharizardMega Charizard Y      Fire           Fire
# 9                    Squirtle     Water         Normal
# 10                  Wartortle     Water         Poison
# 11                  Blastoise     Water          Water
# 12    BlastoiseMega Blastoise     Water          Water
# 13                   Caterpie       Bug            Bug
# 14                    Metapod       Bug            Bug
# 15                 Butterfree       Bug          Grass
# 16                     Weedle       Bug            Bug
# 17                     Kakuna       Bug            Bug
# 18                   Beedrill       Bug         Normal
# 19      BeedrillMega Beedrill       Bug         Normal
# 20                     Pidgey    Normal         Normal
# 21                  Pidgeotto    Normal         Normal
# 22                    Pidgeot    Normal         Normal
# 23        PidgeotMega Pidgeot    Normal       Electric
# 24                    Rattata    Normal         Normal
# 25                   Raticate    Normal         Normal
# 26                    Spearow    Normal         Normal
# 27                     Fearow    Normal         Normal
# 28                      Ekans    Poison         Normal
# 29                      Arbok    Poison         Normal
# 30                    Pikachu  Electric          Water
# 31                     Raichu  Electric           Fire
# 32                  Sandshrew    Ground           Rock
# 33                  Sandslash    Ground           Rock
# 34                   Nidoran♀    Poison         Poison
# 35                   Nidorina    Poison         Normal
# 36                  Nidoqueen    Poison          Water
# 37                   Nidoran♂    Poison         Normal
# 38                   Nidorino    Poison           Fire
# 39                   Nidoking    Poison           Fire
#
#    Neural Network Prediction Random Forest Preduction SVM Prediction
# 0                      Water                    Grass          Water
# 1                      Water                    Grass          Water
# 2                      Water                    Grass          Water
# 3                      Water                    Grass          Water
# 4                      Water                     Fire          Water
# 5                      Water                     Fire          Water
# 6                      Water                     Fire          Water
# 7                      Water                     Fire          Water
# 8                    Psychic                  Psychic        Psychic
# 9                        Bug                    Water          Water
# 10                     Water                    Grass          Water
# 11                     Water                    Water          Water
# 12                     Water                    Grass          Water
# 13                       Bug                      Bug         Normal
# 14                       Bug                      Bug         Normal
# 15                   Psychic                    Grass          Water
# 16                       Bug                      Bug         Normal
# 17                       Bug                      Bug         Normal
# 18                       Bug                      Bug         Normal
# 19                       Bug                      Bug         Normal
# 20                       Bug                   Normal            Bug
# 21                     Water                   Normal         Normal
# 22                    Normal                   Normal         Normal
# 23                   Psychic                 Electric       Electric
# 24                       Bug                   Normal            Bug
# 25                       Bug                   Normal         Normal
# 26                       Bug                   Normal         Normal
# 27                    Normal                   Normal         Normal
# 28                       Bug                   Poison          Water
# 29                     Water                   Poison          Water
# 30                    Normal                    Water          Water
# 31                     Water                 Electric          Water
# 32                       Bug                   Ground            Bug
# 33                       Bug                   Ground         Ground
# 34                       Bug                   Poison          Water
# 35                     Water                   Poison          Water
# 36                     Water                   Poison          Water
# 37                       Bug                   Poison         Normal
# 38                     Water                   Poison         Normal
# 39                     Water                   Poison          Water

# %%
# All Models - Legendary Status

scores = []
for i in range(0,51):
    #Neural Network
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=i)
    X_scaler = StandardScaler().fit(X_train)
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    label_encoder = LabelEncoder()


    y_train_categorical = to_categorical(y_train)
    y_test_categorical = to_categorical(y_test)
    
    model = Sequential()
    model.add(Dense(units=6, activation='relu', input_dim=8))
    model.add(Dense(units=2, activation='softmax'))
    
    model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    
    history = model.fit(
        X_train_scaled,
        y_train_categorical,
        epochs=100,
        shuffle = True,
        verbose = 0,
        validation_data=(X_test_scaled,y_test_categorical)
    )
    model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=0)
    

    print('NN Test Acc: %.3f' % model_accuracy)
    
    #KNN 
    
    knn = KNeighborsClassifier(n_neighbors=17)
    knn.fit(X_train_scaled, y_train)
    knn_score = knn.score(X_test_scaled, y_test)
    print('KNN Test Acc: %.3f' % knn_score)
    
    #Random Forest
    
    rf = RandomForestClassifier (n_estimators=300)
    rf = rf.fit(X_train, y_train)
    rf_score = rf.score(X_test, y_test)
    
    print('RF Test Acc: %.3f' % rf_score)
    
    # SVM
    
    svm_model = SVC(kernel='linear')

    svm_model.fit(X_train, y_train)
    SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
      decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
      max_iter=-1, probability=False, random_state=None, shrinking=True,
      tol=0.001, verbose=False)
    
    svm_score = svm_model.score(X_test, y_test)
    
    print('SVM Test Acc: %.3f' % svm_score)
    

    
    legendary_array.append([model_accuracy, knn_score, rf_score, svm_score])


legendary_df = pd.DataFrame(legendary_array, columns = ['Neural Network', 'KNN', 'Random Forest', 'SVM'])

legendary_df.to_csv('generated_data/legendary_models.csv')

legendary_df.head()
# Out:
# NN Test Acc: 0.955
# KNN Test Acc: 0.945
# RF Test Acc: 0.950
# SVM Test Acc: 0.940
# NN Test Acc: 0.950
# KNN Test Acc: 0.930
# RF Test Acc: 0.940
# SVM Test Acc: 0.925
# NN Test Acc: 0.965
# KNN Test Acc: 0.940
# RF Test Acc: 0.960
# SVM Test Acc: 0.955
# NN Test Acc: 0.940
# KNN Test Acc: 0.945
# RF Test Acc: 0.960
# SVM Test Acc: 0.950
# NN Test Acc: 0.950
# KNN Test Acc: 0.945
# RF Test Acc: 0.955
# SVM Test Acc: 0.945
# NN Test Acc: 0.955
# KNN Test Acc: 0.935
# NN Test Acc: 0.960
# KNN Test Acc: 0.950
# RF Test Acc: 0.970
# SVM Test Acc: 0.960
# NN Test Acc: 0.935
# KNN Test Acc: 0.945
# RF Test Acc: 0.960
# SVM Test Acc: 0.930
# NN Test Acc: 0.930
# KNN Test Acc: 0.930
# RF Test Acc: 0.940
# SVM Test Acc: 0.930
# NN Test Acc: 0.950
# KNN Test Acc: 0.940
# RF Test Acc: 0.945
# SVM Test Acc: 0.935
# NN Test Acc: 0.950
# KNN Test Acc: 0.950
# RF Test Acc: 0.965
# SVM Test Acc: 0.965
# NN Test Acc: 0.935
# KNN Test Acc: 0.930
# RF Test Acc: 0.935
# SVM Test Acc: 0.935
# NN Test Acc: 0.950
# KNN Test Acc: 0.950
# RF Test Acc: 0.955
# SVM Test Acc: 0.930
# NN Test Acc: 0.935
# KNN Test Acc: 0.930
# RF Test Acc: 0.940
# SVM Test Acc: 0.930
# NN Test Acc: 0.920
# KNN Test Acc: 0.945
# RF Test Acc: 0.950
# SVM Test Acc: 0.955
# NN Test Acc: 0.920
# KNN Test Acc: 0.940
# RF Test Acc: 0.950
# SVM Test Acc: 0.925
# NN Test Acc: 0.915
# KNN Test Acc: 0.925
# RF Test Acc: 0.955
# SVM Test Acc: 0.930
# NN Test Acc: 0.945
# KNN Test Acc: 0.935
# RF Test Acc: 0.960
# SVM Test Acc: 0.935
# NN Test Acc: 0.955
# KNN Test Acc: 0.950
# RF Test Acc: 0.950
# SVM Test Acc: 0.940
# NN Test Acc: 0.950
# KNN Test Acc: 0.955
# RF Test Acc: 0.955
# SVM Test Acc: 0.945
# NN Test Acc: 0.940
# KNN Test Acc: 0.950
# RF Test Acc: 0.940
# SVM Test Acc: 0.945
# NN Test Acc: 0.945
# KNN Test Acc: 0.945
# RF Test Acc: 0.965
# SVM Test Acc: 0.955
# NN Test Acc: 0.950
# KNN Test Acc: 0.940
# RF Test Acc: 0.955
# SVM Test Acc: 0.940
# NN Test Acc: 0.950
# KNN Test Acc: 0.950
# RF Test Acc: 0.955
# SVM Test Acc: 0.955
# NN Test Acc: 0.965
# KNN Test Acc: 0.955
# RF Test Acc: 0.975
# SVM Test Acc: 0.940
#    Neural Network    KNN  Random Forest    SVM
# 0           0.955  0.945          0.950  0.940
# 1           0.950  0.930          0.940  0.925
# 2           0.965  0.940          0.960  0.955
# 3           0.940  0.945          0.960  0.950
# 4           0.950  0.945          0.955  0.945

# %%
boxplot = legendary_df.boxplot(column=['Neural Network', 'KNN', 'Random Forest', 'SVM'])

boxplot.set_title('Legendary Status - Model Accuracy')
boxplot.set_xlabel('Model Type')
boxplot.set_ylabel('Model Accuracy')

boxplot.figure.savefig('images/legendary_accuracy.png')

# %%
# Comparison of Predictions By Type 1
predictions = pokedex[['Name',"Legendary"]]
# KNN Predictions
predicted_class_knn = knn.predict(X_scaler.transform(X))
# Neural Network Predictions
predicted_class_nn = model.predict_classes(X_scaler.transform(X))
# Random Forest Predictions
predicted_class_rf = rf.predict(X)
# SVM Predictions
predicted_class_svm = svm_model.predict(X)
# Creating a dataframe to compare data
predictions['KNN Prediction'] = predicted_class_knn
predictions['Neural Network Prediction'] = predicted_class_nn
predictions['Random Forest Preduction'] = predicted_class_rf
predictions['SVM Prediction'] = predicted_class_svm


predictions.to_csv('generated_data/legendary_predictions_accuracy.csv')

predictions.head(40)
# Out:
# /Users/danielbernal/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# <ipython-input-7-483c40853e71>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictions['KNN Prediction'] = predicted_class_knn
# <ipython-input-7-483c40853e71>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictions['Neural Network Prediction'] = predicted_class_nn
# <ipython-input-7-483c40853e71>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictions['Random Forest Preduction'] = predicted_class_rf
# <ipython-input-7-483c40853e71>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictions['SVM Prediction'] = predicted_class_svm
#                          Name  Legendary  KNN Prediction  \
# 0                   Bulbasaur      False           False
# 1                     Ivysaur      False           False
# 2                    Venusaur      False           False
# 3       VenusaurMega Venusaur      False           False
# 4                  Charmander      False           False
# 5                  Charmeleon      False           False
# 6                   Charizard      False           False
# 7   CharizardMega Charizard X      False           False
# 8   CharizardMega Charizard Y      False           False
# 9                    Squirtle      False           False
# 10                  Wartortle      False           False
# 11                  Blastoise      False           False
# 12    BlastoiseMega Blastoise      False           False
# 13                   Caterpie      False           False
# 14                    Metapod      False           False
# 15                 Butterfree      False           False
# 16                     Weedle      False           False
# 17                     Kakuna      False           False
# 18                   Beedrill      False           False
# 19      BeedrillMega Beedrill      False           False
# 20                     Pidgey      False           False
# 21                  Pidgeotto      False           False
# 22                    Pidgeot      False           False
# 23        PidgeotMega Pidgeot      False           False
# 24                    Rattata      False           False
# 25                   Raticate      False           False
# 26                    Spearow      False           False
# 27                     Fearow      False           False
# 28                      Ekans      False           False
# 29                      Arbok      False           False
# 30                    Pikachu      False           False
# 31                     Raichu      False           False
# 32                  Sandshrew      False           False
# 33                  Sandslash      False           False
# 34                   Nidoran♀      False           False
# 35                   Nidorina      False           False
# 36                  Nidoqueen      False           False
# 37                   Nidoran♂      False           False
# 38                   Nidorino      False           False
# 39                   Nidoking      False           False
#
#     Neural Network Prediction  Random Forest Preduction  SVM Prediction
# 0                           0                     False           False
# 1                           0                     False           False
# 2                           0                     False           False
# 3                           0                     False           False
# 4                           0                     False           False
# 5                           0                     False           False
# 6                           0                     False           False
# 7                           0                     False           False
# 8                           0                     False           False
# 9                           0                     False           False
# 10                          0                     False           False
# 11                          0                     False           False
# 12                          0                     False           False
# 13                          0                     False           False
# 14                          0                     False           False
# 15                          0                     False           False
# 16                          0                     False           False
# 17                          0                     False           False
# 18                          0                     False           False
# 19                          0                     False           False
# 20                          0                     False           False
# 21                          0                     False           False
# 22                          0                     False           False
# 23                          0                     False           False
# 24                          0                     False           False
# 25                          0                     False           False
# 26                          0                     False           False
# 27                          0                     False           False
# 28                          0                     False           False
# 29                          0                     False           False
# 30                          0                     False           False
# 31                          0                     False           False
# 32                          0                     False           False
# 33                          0                     False           False
# 34                          0                     False           False
# 35                          0                     False           False
# 36                          0                     False           False
# 37                          0                     False           False
# 38                          0                     False           False
# 39                          0                     False           False
